# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pdpbox 0.2.1 requires sklearn, which is not installed.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# pdpbox 0.2.1 requires matplotlib==3.1.1, but you have matplotlib 3.6.3 which is incompatible.
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scipy<1.10,>=1.4.1
#   Using cached scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (1.5.3)
# Collecting matplotlib<3.7,>=3.2
#   Using cached matplotlib-3.6.3-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting pydantic<1.11,>=1.8.1
#   Using cached pydantic-1.10.7-cp310-cp310-win_amd64.whl (2.1 MB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (3.1.2)
# Collecting visions[type_image_path]==0.7.5
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (0.1.12)
# Collecting phik<0.13,>=0.11.1
#   Using cached phik-0.12.3-cp310-cp310-win_amd64.whl (663 kB)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (2.28.1)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (4.64.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (0.12.2)
# Collecting multimethod<1.10,>=1.4
#   Using cached multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (0.13.5)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\rajas\anaconda3\lib\site-packages (from ydata-profiling==0.0.dev0) (2.13.3)
# Collecting imagehash==4.3.1
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Requirement already satisfied: PyWavelets in c:\users\rajas\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (1.4.1)
# Requirement already satisfied: pillow in c:\users\rajas\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (9.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\rajas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (2.8.4)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\rajas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\rajas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (22.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rajas\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==0.0.dev0) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling==0.0.dev0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling==0.0.dev0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling==0.0.dev0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling==0.0.dev0) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling==0.0.dev0) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling==0.0.dev0) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling==0.0.dev0) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajas\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling==0.0.dev0) (2022.7)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\rajas\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling==0.0.dev0) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\rajas\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling==0.0.dev0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling==0.0.dev0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling==0.0.dev0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rajas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling==0.0.dev0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling==0.0.dev0) (1.26.14)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\rajas\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling==0.0.dev0) (0.5.3)
# Requirement already satisfied: colorama in c:\users\rajas\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->ydata-profiling==0.0.dev0) (0.4.6)
# Requirement already satisfied: six in c:\users\rajas\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling==0.0.dev0) (1.16.0)
# Building wheels for collected packages: ydata-profiling
#   Building wheel for ydata-profiling (setup.py): started
#   Building wheel for ydata-profiling (setup.py): finished with status 'done'
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=346020 sha256=d203c69a346759c0c8ea83f44645810462db98c33b54c1f710311076c3c05d30
#   Stored in directory: C:\Users\rajas\AppData\Local\Temp\pip-ephem-wheel-cache-mop_0xy1\wheels\07\29\61\f533cc7cbd0a97efb2d1b94d3254a3e859a949367ba842577b
# Successfully built ydata-profiling
# Installing collected packages: scipy, pydantic, multimethod, matplotlib, imagehash, visions, phik, ydata-profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.0
#     Uninstalling scipy-1.10.0:
#       Successfully uninstalled scipy-1.10.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.0
#     Uninstalling matplotlib-3.7.0:
#       Successfully uninstalled matplotlib-3.7.0
# Successfully installed imagehash-4.3.1 matplotlib-3.6.3 multimethod-1.9.1 phik-0.12.3 pydantic-1.10.7 scipy-1.9.3 visions-0.7.5 ydata-profiling-0.0.dev0

# %%
# !pip install explainerdashboard
# Out:
# Collecting explainerdashboard
#   Downloading explainerdashboard-0.4.2.1-py3-none-any.whl (286 kB)
#      -------------------------------------- 286.9/286.9 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.2.1)
# Requirement already satisfied: shap>=0.37 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (0.41.0)
# Requirement already satisfied: joblib in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.1.1)
# Collecting dash-bootstrap-components>=1
#   Downloading dash_bootstrap_components-1.4.1-py3-none-any.whl (220 kB)
#      -------------------------------------- 220.6/220.6 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (8.0.4)
# Collecting oyaml
#   Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Collecting dash-auth
#   Downloading dash_auth-2.0.0-py3-none-any.whl (3.4 kB)
# Requirement already satisfied: graphviz>=0.18.2 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (0.20.1)
# Collecting dash>=2.3.1
#   Downloading dash-2.9.3-py3-none-any.whl (10.2 MB)
#      --------------------------------------- 10.2/10.2 MB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.23.5)
# Collecting jupyter-dash>=0.4.1
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.5.3)
# Collecting flask-simplelogin
#   Downloading flask_simplelogin-0.1.1-py3-none-any.whl (7.2 kB)
# Collecting waitress
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.7/57.7 kB 1.5 MB/s eta 0:00:00
# Collecting dtreeviz>=2.1
#   Downloading dtreeviz-2.2.1-py3-none-any.whl (91 kB)
#      ---------------------------------------- 91.5/91.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=5.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (5.9.0)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\rajas\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (2.2.2)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: pytest in c:\users\rajas\anaconda3\lib\site-packages (from dtreeviz>=2.1->explainerdashboard) (7.1.2)
# Requirement already satisfied: matplotlib in c:\users\rajas\anaconda3\lib\site-packages (from dtreeviz>=2.1->explainerdashboard) (3.7.0)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: ipykernel in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (6.19.2)
# Requirement already satisfied: ipython in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (8.10.0)
# Requirement already satisfied: nest-asyncio in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (1.5.6)
# Requirement already satisfied: requests in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (2.28.1)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rajas\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajas\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2022.7)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\rajas\anaconda3\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (2.2.0)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (4.64.1)
# Requirement already satisfied: cloudpickle in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (2.0.0)
# Requirement already satisfied: packaging>20.9 in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (22.0)
# Requirement already satisfied: numba in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (0.56.4)
# Requirement already satisfied: slicer==0.0.7 in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (0.0.7)
# Requirement already satisfied: colorama in c:\users\rajas\anaconda3\lib\site-packages (from click->explainerdashboard) (0.4.6)
# Collecting Flask-WTF<0.16.0,>=0.15.1
#   Downloading Flask_WTF-0.15.1-py2.py3-none-any.whl (13 kB)
# Collecting WTForms>=2.1
#   Downloading WTForms-3.0.1-py3-none-any.whl (136 kB)
#      -------------------------------------- 136.5/136.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in c:\users\rajas\anaconda3\lib\site-packages (from oyaml->explainerdashboard) (6.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\rajas\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\rajas\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\rajas\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rajas\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.3.1->explainerdashboard) (8.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\rajas\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->explainerdashboard) (1.16.0)
# Requirement already satisfied: MarkupSafe in c:\users\rajas\anaconda3\lib\site-packages (from WTForms>=2.1->flask-simplelogin->explainerdashboard) (2.1.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (7.3.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.7.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (6.1)
# Requirement already satisfied: psutil in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.18.1)
# Requirement already satisfied: backcall in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.7.5)
# Requirement already satisfied: decorator in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (5.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.4.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\rajas\anaconda3\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\rajas\anaconda3\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (65.6.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (22.1.0)
# Requirement already satisfied: iniconfig in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\rajas\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.2.0)
# Requirement already satisfied: entrypoints in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.4)
# Requirement already satisfied: wcwidth in c:\users\rajas\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.5)
# Requirement already satisfied: executing in c:\users\rajas\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\rajas\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\rajas\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.0.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (2.5.2)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, colour, WTForms, waitress, retrying, oyaml, ansi2html, Flask-WTF, dtreeviz, dash, flask-simplelogin, dash-bootstrap-components, dash-auth, jupyter-dash, explainerdashboard
# Successfully installed Flask-WTF-0.15.1 WTForms-3.0.1 ansi2html-1.8.0 colour-0.1.5 dash-2.9.3 dash-auth-2.0.0 dash-bootstrap-components-1.4.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 dtreeviz-2.2.1 explainerdashboard-0.4.2.1 flask-simplelogin-0.1.1 jupyter-dash-0.4.2 oyaml-1.0 retrying-1.3.4 waitress-2.1.2

# %%
# !pip install explainerdashboard
# Out:
# Requirement already satisfied: explainerdashboard in c:\users\rajas\anaconda3\lib\site-packages (0.4.2.1)
# Requirement already satisfied: graphviz>=0.18.2 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (0.20.1)
# Requirement already satisfied: shap>=0.37 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (0.41.0)
# Requirement already satisfied: dtreeviz>=2.1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (2.2.1)
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.2.1)
# Requirement already satisfied: waitress in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (2.1.2)
# Requirement already satisfied: oyaml in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.0)
# Requirement already satisfied: click in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (8.0.4)
# Requirement already satisfied: dash-auth in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (2.0.0)
# Requirement already satisfied: joblib in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.1.1)
# Requirement already satisfied: pandas>=1.1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.5.3)
# Requirement already satisfied: jupyter-dash>=0.4.1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (0.4.2)
# Requirement already satisfied: numpy in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.23.5)
# Requirement already satisfied: dash>=2.3.1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (2.9.3)
# Requirement already satisfied: dash-bootstrap-components>=1 in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (1.4.1)
# Requirement already satisfied: flask-simplelogin in c:\users\rajas\anaconda3\lib\site-packages (from explainerdashboard) (0.1.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (5.9.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\rajas\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (2.2.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: matplotlib in c:\users\rajas\anaconda3\lib\site-packages (from dtreeviz>=2.1->explainerdashboard) (3.6.3)
# Requirement already satisfied: pytest in c:\users\rajas\anaconda3\lib\site-packages (from dtreeviz>=2.1->explainerdashboard) (7.1.2)
# Requirement already satisfied: colour in c:\users\rajas\anaconda3\lib\site-packages (from dtreeviz>=2.1->explainerdashboard) (0.1.5)
# Requirement already satisfied: nest-asyncio in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (6.19.2)
# Requirement already satisfied: requests in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (2.28.1)
# Requirement already satisfied: ipython in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (8.10.0)
# Requirement already satisfied: retrying in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (1.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajas\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rajas\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\rajas\anaconda3\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (2.2.0)
# Requirement already satisfied: cloudpickle in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (2.0.0)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (4.64.1)
# Requirement already satisfied: packaging>20.9 in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (22.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (0.0.7)
# Requirement already satisfied: numba in c:\users\rajas\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (0.56.4)
# Requirement already satisfied: colorama in c:\users\rajas\anaconda3\lib\site-packages (from click->explainerdashboard) (0.4.6)
# Requirement already satisfied: Flask-WTF<0.16.0,>=0.15.1 in c:\users\rajas\anaconda3\lib\site-packages (from flask-simplelogin->explainerdashboard) (0.15.1)
# Requirement already satisfied: WTForms>=2.1 in c:\users\rajas\anaconda3\lib\site-packages (from flask-simplelogin->explainerdashboard) (3.0.1)
# Requirement already satisfied: pyyaml in c:\users\rajas\anaconda3\lib\site-packages (from oyaml->explainerdashboard) (6.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\rajas\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\rajas\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\rajas\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.2.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rajas\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.3.1->explainerdashboard) (8.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\rajas\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->explainerdashboard) (1.16.0)
# Requirement already satisfied: MarkupSafe in c:\users\rajas\anaconda3\lib\site-packages (from WTForms>=2.1->flask-simplelogin->explainerdashboard) (2.1.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (6.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.7.1)
# Requirement already satisfied: psutil in c:\users\rajas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.9.0)
# Requirement already satisfied: pickleshare in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.11.2)
# Requirement already satisfied: backcall in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.18.1)
# Requirement already satisfied: decorator in c:\users\rajas\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (5.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajas\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (4.25.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\rajas\anaconda3\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\rajas\anaconda3\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (65.6.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (22.1.0)
# Requirement already satisfied: iniconfig in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\rajas\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajas\anaconda3\lib\site-packages (from requests->jupyter-dash>=0.4.1->explainerdashboard) (2022.12.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\rajas\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.2.0)
# Requirement already satisfied: wcwidth in c:\users\rajas\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.5)
# Requirement already satisfied: executing in c:\users\rajas\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\rajas\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\rajas\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rajas\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (2.5.2)

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline
sns.set_style(style="darkgrid")
plt.style.use("bmh")

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.float','{:.2f}'.format)

# %%
# file_path = "/content/drive/MyDrive/LJMU/Dataset/UCI/cleveland.data"
# # above .data file is comma delimited
# with open(file_path, encoding="utf8", errors='ignore') as f:
#   wine_data = pd.read_csv(file_path, delimiter=",")
